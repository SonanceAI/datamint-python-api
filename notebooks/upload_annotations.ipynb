# %% [markdown]
# # Intro
# This notebook shows how to:
# - upload image label annotations
# - upload image category annotations
#
#
# Our example project looks like this:
#
# | ![image.png](attachment:image.png) |
# |-|

# %% [markdown]
# # Uploading image labels

# %%
from datetime import date
from tqdm.auto import tqdm
from datamint import APIHandler

api = APIHandler()
# resources = list(api.get_resources(project_name="My Project"))
# resource_id = resources[0]["id"]

# %%
# Adds an annotation to a single resource, associated with a project.
api.add_annotations(resource_id=resource_id,
                    identifier='img-lb1',
                    project='Example Project' # You can pass None to use not associated with a project
                    )

# %% [markdown]
# # Uploading image categories

# %%
# Adds an annotation to a single resource, associated with a project.
api.add_image_category_annotation(resource_id,
                                  identifier='img-cls',
                                  value='cls1',
                                  project='Example Project' # You can pass None to use not associated with a project
                                  )
